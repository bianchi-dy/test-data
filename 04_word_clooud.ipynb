# %%
import pandas as pd
df = pd.read_csv('signals.csv')
df
# Out:
#     Big themes (5 only)                     Themes  \
# 0     A New World Order  Changing economic systems
# 1     A New World Order  Changing economic systems
# 2     A New World Order  Changing economic systems
# 3     A New World Order  Changing economic systems
# 4     A New World Order  Changing economic systems
# ..                  ...                        ...
# 197   Our Connectedness                      Trust
# 198   Our Connectedness                      Trust
# 199   Our Connectedness                      Trust
# 200   Our Connectedness                      Trust
# 201   Our Connectedness                      Trust
#
#                           Signals  Count
# 0    alternative economic systems      3
# 1                  liberalisation      2
# 2           new forms of currency      1
# 3         new types of businesses      1
# 4          new ways of investment      1
# ..                            ...    ...
# 197     increased social distrust      1
# ...

# %%
df.groupby(['Signals']).agg({'Count': sum}).reset_index().sort_values('Count').to_csv('data/signals-counted-wordcloud.csv')
